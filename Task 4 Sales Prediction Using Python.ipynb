# %% [markdown]
# # CodSoft Internship Task 4 : Sales Prediction Using Python

# %%
# Importing the libraries 
import pandas as pd 
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
df = pd.read_csv('advertising.csv') # Data loading

# %% [markdown]
# # Data Exploration

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
plt.boxplot(df,vert=True,patch_artist=True); # Checking the Outliers

# %% [markdown]
# # Splitting  and Model Training

# %%
x=df[['TV','Radio','Newspaper']]
y=df['Sales']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=linear_model.LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test) # Model testing
# Out:
# array([14.82054661, 19.03050742, 20.3628045 ,  9.46986594, 16.35212389,
#        24.10144092, 10.65013421, 20.06791771,  8.94498317, 20.72244459,
#        17.21149236,  9.47137893, 15.16060275, 17.99004751, 20.9134125 ,
#        21.48950044,  8.79050464,  8.74062065, 20.90778493, 16.33498947,
#         7.12235537, 16.8208947 , 20.6531838 , 24.77889489, 13.97458813,
#        18.70578815, 19.01018102,  9.25184094, 11.73381206, 20.67224365,
#        16.73015389,  8.31959798, 19.41445598, 18.04599381, 19.46139004,
#         8.84604376, 15.49614243, 12.43507201,  7.95081542, 12.44205138])

# %%
model.score(x_test,y_test) # Accuracy Evaluation
# Out:
# 0.9130031621077275

# %%
# New prediction
'''TV=23
Radio=35
Newspaper=45'''
new_entry=[[23,35,45]]
predicted_sales=model.predict(new_entry)
print('Predicted sales is : ',predicted_sales)
# Out:
# Predicted sales is :  [9.58527489]
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # column seperation

# %%
newspaper=df['Newspaper'].values
radio=df['Radio'].values
tv=df['TV'].values
sales=df['Sales'].values

# %%
# Visualization

# %%
sum_tv=df['TV'].sum()
sum_radio=df['Radio'].sum()
sum_newspaper=df['Newspaper'].sum()

sums=[sum_tv,sum_radio,sum_newspaper]
domains=['TV','Radio','Newspaper']

plt.figure(figsize=(10, 5))
plt.bar(domains,sums,color=['purple','green','skyblue'])

plt.xlabel('Advertising Platform')
plt.ylabel('Total Expenditure')
plt.title('Total Expenditure per Advertising Platform')
plt.grid(True)

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(data=df, x='TV', y='Sales') 
plt.title('Expenditures on TV Advertisement vs Sales') 
plt.xticks(np.arange(-0, 300, 20))
plt.grid(True)
#Invest on TV Advertisement Would be beneficial because Sales are Increasing along with TV Advertisement

# %%
plt.figure(figsize=(15, 5))
plt.hist(tv, bins=30, edgecolor='black')  
plt.xlabel('Expenditure on TV Advertisement')  
plt.ylabel('Sales') 
plt.title('Distribution of Expenditure on TV Advertisement vs Sales')  
plt.grid(True)  
plt.xticks(np.arange(0, 300, 10))
# Out:
# ([<matplotlib.axis.XTick at 0x22b10209b80>,
# ...
#  [Text(0, 0, '0'),
#   Text(10, 0, '10'),
#   Text(20, 0, '20'),
#   Text(30, 0, '30'),
#   Text(40, 0, '40'),
#   Text(50, 0, '50'),
#   Text(60, 0, '60'),
#   Text(70, 0, '70'),
#   Text(80, 0, '80'),
#   Text(90, 0, '90'),
#   Text(100, 0, '100'),
#   Text(110, 0, '110'),
#   Text(120, 0, '120'),
#   Text(130, 0, '130'),
#   Text(140, 0, '140'),
#   Text(150, 0, '150'),
#   Text(160, 0, '160'),
#   Text(170, 0, '170'),
#   Text(180, 0, '180'),
#   Text(190, 0, '190'),
#   Text(200, 0, '200'),
#   Text(210, 0, '210'),
#   Text(220, 0, '220'),
#   Text(230, 0, '230'),
#   Text(240, 0, '240'),
#   Text(250, 0, '250'),
#   Text(260, 0, '260'),
#   Text(270, 0, '270'),
#   Text(280, 0, '280'),
#   Text(290, 0, '290')])

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(data=df, x='Radio', y='Sales') 
plt.title('Expenditures on radio Advertisement vs Sales') 
plt.grid(True)

# %%
plt.figure(figsize=(15, 5))
plt.hist(radio,bins=30)
plt.xticks(np.arange(-0, 60, 2))
plt.xlabel('Expenditure on Radio Advertisement')
plt.ylabel('SALES')
plt.grid(True)

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(data=df, x='Newspaper', y='Sales') 
plt.title('Expenditure on Newspaper Advertisement vs Sales') 
plt.grid(True)

# %%
plt.figure(figsize=(15, 5))
plt.hist(newspaper,bins=30)
plt.xticks(np.arange(-0, 120, 5))
plt.xlabel('EXPENDITURE ON NEWSPAPER Advertisement')
plt.ylabel('SALES')
plt.grid(True)
